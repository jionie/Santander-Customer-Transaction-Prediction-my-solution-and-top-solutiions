# %%
import numpy as np
import pandas as pd
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import KFold

from bayes_opt import BayesianOptimization
import lightgbm as lgb

import os

from sklearn.cluster import KMeans

from sklearn.neighbors import DistanceMetric

from xgboost import XGBClassifier

# %%
# control parameters
nfolds = 5

# %% [markdown]
# # Data

# %%
xtrain = pd.read_csv("../input/train.csv")
xtest = pd.read_csv("../input/test.csv")

# %%
# separate the data
id_train = xtrain['ID_code']
ytrain = xtrain['target']
id_test = xtest['ID_code']
xtrain.drop(['ID_code', 'target'], axis = 1, inplace = True)
xtest.drop('ID_code', axis = 1, inplace = True)

# %%
folds = KFold(n_splits= nfolds, shuffle=True, random_state= 15)

mindex  = np.zeros((len(xtrain),1) )

for fold_, (trn_idx, val_idx) in enumerate(folds.split(xtrain.values, ytrain.values)):
#    print('----')
    print("fold n°{}".format(fold_))
    
    mindex[val_idx, 0] = fold_

xfolds = pd.DataFrame()
xfolds['MachineIdentifier'] = id_train
xfolds['fold_id']= mindex
xfolds['fold_id'] = xfolds['fold_id'].astype(int).round(0)
xfolds.to_csv('xfolds.csv', index = False)
# Out:
# fold n°0
# fold n°1
# fold n°2
# fold n°3
# fold n°4

# %% [markdown]
# # FE

# %% [markdown]
# ## Clustering

# %%
kmeans = KMeans(init='k-means++', n_clusters= 10, n_init=10)
kmeans.fit(xtrain)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=10, n_init=10, n_jobs=None, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
# distance of each observation from cluster centers
dist = DistanceMetric.get_metric('euclidean')
ax_tr = dist.pairwise(xtrain, kmeans.cluster_centers_)
ax_te = dist.pairwise(xtest, kmeans.cluster_centers_)

# %%
# format into dataframe
ax_tr = pd.DataFrame(ax_tr)
ax_te = pd.DataFrame(ax_te)
xcols =  ['dist' + str(f) for f in range(0, ax_tr.shape[1])]

# %%
ax_tr.columns = xcols
ax_te.columns = xcols

# %% [markdown]
# ## Summary statistics

# %%
m1 = xtrain.max(axis = 1)
m2 = xtrain.min(axis = 1)
m3 = xtrain.median(axis = 1)
m4 = 1/xtrain.std(axis = 1)
m5 = 1/xtrain.mad(axis = 1)

xtrain['xmax'] = m1; xtrain['xmin'] = m2; xtrain['xmed'] = m3; xtrain['xstd'] = m4

m1 = xtest.max(axis = 1)
m2 = xtest.min(axis = 1)
m3 = xtest.median(axis = 1)
m4 = 1/xtest.std(axis = 1)
m5 = 1/xtest.mad(axis = 1)

xtest['xmax'] = m1; xtest['xmin'] = m2; xtest['xmed'] = m3; xtest['xstd'] = m4

# %%
# combine
xtrain = pd.concat([xtrain, ax_tr], axis = 1)
xtest = pd.concat([xtest, ax_te], axis = 1)

# %%
xtrain.head(3)
# Out:
#      var_0   var_1    var_2    ...          dist7      dist8      dist9
# 0   8.9255 -6.7863  11.9081    ...      74.500807  79.435260  77.726521
# 1  11.5006 -4.1473  13.8588    ...      94.982223  95.812135  90.644216
# 2   8.6093 -2.7457  12.0805    ...      73.877706  71.461238  68.719158
#
# [3 rows x 214 columns]

# %% [markdown]
# # Parameter tuning

# %%
def lgbcv(learning_rate, subsample, min_child_samples, max_depth,
                  colsample_bytree, min_child_weight, min_split_gain, 
                  lambda_l1, lambda_l2,bagging_freq, num_leaves,
                  silent=True, seed=1234):

    params = {                        
            'boosting_type': 'gbdt','objective': 'binary', 'metric':'auc',
            'max_depth': -1, 'num_leaves': int(num_leaves),
            'learning_rate': learning_rate, 'max_depth': int(max_depth),
            'min_child_samples': int(min_child_samples), 
           'subsample': subsample, 'colsample_bytree': colsample_bytree, 'bagging_seed': 11,
           'min_child_weight': min_child_weight,  'bagging_freq' : int(bagging_freq),
           'min_split_gain': min_split_gain,'lambda_l1': lambda_l1,'lambda_l2': lambda_l2,
           'nthread': 8
        }

                
    bst1 = lgb.train(params, trn_data, valid_sets=[trn_data, val_data], valid_names=['train','valid'],
                          num_boost_round= 5000, verbose_eval= 5000, early_stopping_rounds = 100)
    
    ypred = bst1.predict(x1)

    loss = roc_auc_score(y1, ypred)
    return loss

# %%
## find optimal params
param_list = list()
score_list = list()


for fold_, (trn_idx, val_idx) in enumerate(folds.split(xtrain.values, ytrain.values)):
    print('----')
    print("fold n°{}".format(fold_))
    
    x0,y0 = xtrain.iloc[trn_idx], ytrain[trn_idx]
    x1,y1 = xtrain.iloc[val_idx], ytrain[val_idx]
    
    
    trn_data = lgb.Dataset(x0, label= y0); val_data = lgb.Dataset(x1, label= y1)
    # optimization
    lgbBO = BayesianOptimization(lgbcv, {'learning_rate': (0.0025, 0.05),'max_depth': (int(5), int(15)),
                                           'min_child_samples': (int(25), int(250)),'subsample': (0.2, 0.95),
                                            'colsample_bytree': (0.2, 0.95), 'min_child_weight': (int(1), int(150)),
                                            'min_split_gain': (0.1, 2),'num_leaves': (int(15),int(200)),
                                             'lambda_l1': (10, 200),'lambda_l2': (10, 200),
                                             'bagging_freq': (1,20)
                                                   })
    lgbBO.maximize(init_points= 25, n_iter= 45, xi=0.06)
    print('-' * 53)
    print('Final Results')
    print('LGB: %f' % lgbBO.res['max']['max_val']);  print('LGB: %s' % lgbBO.res['max']['max_params'])

    param_list.append(lgbBO.res['max']['max_params'])
    score_list.append(lgbBO.res['max']['max_val'])
# Out:
# ----
# fold n°0
# |   iter    |  target   | baggin... | colsam... | lambda_l1 | lambda_l2 | learni... | max_depth | min_ch... | min_ch... | min_sp... | num_le... | subsample |
# -------------------------------------------------------------------------------------------------------------------------------------------------------------
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [2022]	train's auc: 0.877751	valid's auc: 0.857724
# |  1        |  0.8577   |  8.75     |  0.9034   |  157.6    |  170.7    |  0.01819  |  9.137    |  197.0    |  147.5    |  1.005    |  41.88    |  0.3509   |
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [828]	train's auc: 0.873127	valid's auc: 0.858794
# |  2        |  0.8588   |  10.88    |  0.4606   |  100.0    |  174.1    |  0.0455   |  6.844    |  226.9    |  55.79    |  1.61     |  25.14    |  0.2289   |
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1504]	train's auc: 0.90263	valid's auc: 0.87643
# |  3        |  0.8764   |  16.48    |  0.7629   |  123.3    |  121.8    |  0.03819  |  12.59    |  140.2    |  133.8    |  0.4072   |  131.5    |  0.3941   |
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [2930]	train's auc: 0.945167	valid's auc: 0.897429
# |  4        |  0.8974   |  1.96     |  0.7272   |  34.7     |  55.97    |  0.03959  |  12.96    |  70.9     |  21.05    |  1.094    |  23.3     |  0.4832   |
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [4695]	train's auc: 0.976461	valid's auc: 0.897254
# |  5        |  0.8973   |  7.369    |  0.8728   |  14.3     |  91.78    |  0.01049  |  14.82    |  54.07    |  51.92    |  0.1429   |  174.3    |  0.6514   |
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [4865]	train's auc: 0.914648	valid's auc: 0.885388
# |  6        |  0.8854   |  9.287    |  0.2756   |  118.7    |  10.87    |  0.01141  |  8.326    |  173.6    |  30.99    |  1.329    |  48.09    |  0.5621   |
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1820]	train's auc: 0.929524	valid's auc: 0.890696
# |  7        |  0.8907   |  18.94    |  0.4039   |  97.6     |  36.93    |  0.03977  |  14.28    |  183.8    |  148.6    |  1.128    |  116.9    |  0.7776   |
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [2332]	train's auc: 0.95497	valid's auc: 0.896465
# |  8        |  0.8965   |  1.278    |  0.8898   |  27.32    |  198.9    |  0.03683  |  7.797    |  57.53    |  73.73    |  1.502    |  33.15    |  0.9492   |
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1121]	train's auc: 0.905581	valid's auc: 0.876963
# |  9        |  0.877    |  14.51    |  0.7028   |  167.7    |  48.63    |  0.04729  |  13.38    |  40.54    |  73.28    |  0.1189   |  198.5    |  0.4089   |
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [4419]	train's auc: 0.902815	valid's auc: 0.878695
# |  10       |  0.8787   |  18.54    |  0.2279   |  157.4    |  119.9    |  0.01437  |  7.609    |  166.2    |  113.1    |  1.247    |  119.5    |  0.6082   |
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1819]	train's auc: 0.918142	valid's auc: 0.88401
# |  11       |  0.884    |  17.75    |  0.228    |  167.1    |  149.8    |  0.03656  |  9.891    |  62.49    |  25.64    |  1.235    |  176.2    |  0.8526   |
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [901]	train's auc: 0.896156	valid's auc: 0.86968
# |  12       |  0.8697   |  9.753    |  0.5481   |  196.2    |  152.2    |  0.04405  |  11.14    |  111.8    |  42.91    |  0.814    |  71.28    |  0.4595   |
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1944]	train's auc: 0.91418	valid's auc: 0.8828
# |  13       |  0.8828   |  19.69    |  0.6756   |  110.3    |  85.91    |  0.02354  |  11.69    |  106.0    |  9.987    |  0.7131   |  37.77    |  0.3621   |
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1866]	train's auc: 0.886151	valid's auc: 0.860029
# |  14       |  0.86     |  13.42    |  0.7636   |  196.8    |  154.8    |  0.02083  |  6.668    |  191.2    |  16.21    |  1.684    |  107.6    |  0.5216   |
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [2309]	train's auc: 0.899079	valid's auc: 0.871776
# |  15       |  0.8718   |  16.22    |  0.9302   |  153.1    |  88.79    |  0.02623  |  5.083    |  136.0    |  50.87    |  0.4655   |  182.3    |  0.4753   |
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [2802]	train's auc: 0.921883	valid's auc: 0.891435
# |  16       |  0.8914   |  5.41     |  0.7768   |  30.11    |  192.7    |  0.03312  |  8.057    |  55.06    |  125.1    |  0.8875   |  79.68    |  0.3285   |
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [3528]	train's auc: 0.9382	valid's auc: 0.89627
# |  17       |  0.8963   |  10.68    |  0.77     |  39.7     |  48.43    |  0.02212  |  7.859    |  61.13    |  117.7    |  1.807    |  94.52    |  0.6577   |
# Training until validation scores don't improve for 100 rounds.
# [5000]	train's auc: 0.899282	valid's auc: 0.881434
# Did not meet early stopping. Best iteration is:
# [5000]	train's auc: 0.899282	valid's auc: 0.881434
# |  18       |  0.8814   |  12.69    |  0.2736   |  68.68    |  161.0    |  0.01294  |  6.672    |  204.5    |  134.1    |  1.134    |  109.9    |  0.3198   |
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [2393]	train's auc: 0.929315	valid's auc: 0.894883
# |  19       |  0.8949   |  8.749    |  0.6922   |  23.06    |  154.5    |  0.03757  |  9.183    |  136.8    |  44.92    |  1.876    |  20.29    |  0.3642   |
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1232]	train's auc: 0.879996	valid's auc: 0.857472
# |  20       |  0.8575   |  2.339    |  0.8463   |  178.2    |  154.1    |  0.03031  |  6.117    |  102.7    |  61.91    |  1.78     |  160.8    |  0.4157   |
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [3063]	train's auc: 0.921522	valid's auc: 0.88163
# |  21       |  0.8816   |  12.76    |  0.4239   |  193.2    |  170.1    |  0.02582  |  7.22     |  112.8    |  86.62    |  0.2311   |  65.06    |  0.9007   |
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1695]	train's auc: 0.927095	valid's auc: 0.883689
# |  22       |  0.8837   |  8.581    |  0.5434   |  167.1    |  118.1    |  0.04344  |  8.061    |  42.84    |  86.38    |  0.2994   |  171.8    |  0.8661   |
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [4847]	train's auc: 0.935555	valid's auc: 0.893625
# |  23       |  0.8936   |  14.39    |  0.3639   |  84.54    |  94.16    |  0.01388  |  11.24    |  224.1    |  22.16    |  0.7006   |  27.41    |  0.6636   |
# Training until validation scores don't improve for 100 rounds.
# [5000]	train's auc: 0.90141	valid's auc: 0.86792
# Did not meet early stopping. Best iteration is:
# [5000]	train's auc: 0.90141	valid's auc: 0.86792
# |  24       |  0.8679   |  15.56    |  0.8196   |  156.4    |  98.69    |  0.005935 |  7.47     |  27.36    |  40.43    |  0.3334   |  168.3    |  0.5732   |
# Training until validation scores don't improve for 100 rounds.
# [5000]	train's auc: 0.918314	valid's auc: 0.869391
# Did not meet early stopping. Best iteration is:
# [5000]	train's auc: 0.918314	valid's auc: 0.869391
# |  25       |  0.8694   |  1.436    |  0.7726   |  81.24    |  103.5    |  0.003309 |  8.795    |  42.34    |  11.07    |  0.508    |  166.7    |  0.8517   |
# Training until validation scores don't improve for 100 rounds.
# [5000]	train's auc: 0.920823	valid's auc: 0.881022
# Did not meet early stopping. Best iteration is:
# [5000]	train's auc: 0.920823	valid's auc: 0.881022
# |  26       |  0.881    |  18.51    |  0.561    |  14.99    |  183.0    |  0.004119 |  8.317    |  243.9    |  12.56    |  1.127    |  198.2    |  0.4255   |
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1072]	train's auc: 0.951181	valid's auc: 0.893074
# |  27       |  0.8931   |  16.9     |  0.7311   |  12.66    |  11.16    |  0.03346  |  11.46    |  236.1    |  22.34    |  1.03     |  137.1    |  0.2865   |
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1671]	train's auc: 0.921997	valid's auc: 0.893709
# |  28       |  0.8937   |  19.61    |  0.4437   |  26.45    |  20.85    |  0.0487   |  5.288    |  249.5    |  120.0    |  0.9032   |  22.83    |  0.3288   |
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [4212]	train's auc: 0.861086	valid's auc: 0.844229
# |  29       |  0.8442   |  13.7     |  0.6508   |  182.7    |  10.38    |  0.00572  |  8.332    |  36.5     |  146.7    |  1.11     |  21.58    |  0.3318   |
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1443]	train's auc: 0.885686	valid's auc: 0.861406
# |  30       |  0.8614   |  19.59    |  0.8049   |  192.2    |  28.5     |  0.03336  |  5.36     |  245.6    |  148.1    |  1.893    |  182.0    |  0.5581   |
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [3452]	train's auc: 0.920151	valid's auc: 0.89343
# |  31       |  0.8934   |  17.47    |  0.8525   |  20.47    |  14.35    |  0.01616  |  8.449    |  33.78    |  148.4    |  1.728    |  198.8    |  0.2834   |
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [2556]	train's auc: 0.885371	valid's auc: 0.863886
# |  32       |  0.8639   |  12.32    |  0.5775   |  194.3    |  197.8    |  0.01462  |  9.357    |  25.41    |  129.2    |  1.767    |  186.5    |  0.484    |
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [3942]	train's auc: 0.941798	valid's auc: 0.89687
# |  33       |  0.8969   |  18.04    |  0.768    |  11.78    |  199.6    |  0.02357  |  5.267    |  28.6     |  5.573    |  1.636    |  77.48    |  0.517    |
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [3616]	train's auc: 0.957557	valid's auc: 0.899244
# |  34       |  0.8992   |  17.86    |  0.6276   |  18.74    |  123.6    |  0.02449  |  13.52    |  40.61    |  144.4    |  0.5854   |  20.47    |  0.8659   |
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [2905]	train's auc: 0.924886	valid's auc: 0.894715
# |  35       |  0.8947   |  1.998    |  0.3567   |  13.03    |  38.69    |  0.03363  |  14.39    |  236.8    |  135.8    |  1.496    |  199.4    |  0.2406   |
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [3629]	train's auc: 0.957128	valid's auc: 0.897944
# |  36       |  0.8979   |  15.47    |  0.8298   |  17.94    |  191.9    |  0.03661  |  5.015    |  33.27    |  29.55    |  1.064    |  198.3    |  0.8775   |
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1967]	train's auc: 0.878643	valid's auc: 0.857234
# |  37       |  0.8572   |  19.05    |  0.3836   |  198.7    |  11.26    |  0.01898  |  6.958    |  242.5    |  23.9     |  1.716    |  25.88    |  0.4668   |
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1595]	train's auc: 0.941433	valid's auc: 0.899232
# |  38       |  0.8992   |  6.962    |  0.3534   |  14.97    |  14.86    |  0.04188  |  12.4     |  198.7    |  2.48     |  0.6357   |  17.8     |  0.4588   |
# Training until validation scores don't improve for 100 rounds.
# [5000]	train's auc: 0.945598	valid's auc: 0.892681
# Did not meet early stopping. Best iteration is:
# [5000]	train's auc: 0.945598	valid's auc: 0.892681
# |  39       |  0.8927   |  18.3     |  0.389    |  12.57    |  18.34    |  0.004136 |  14.12    |  116.0    |  91.59    |  0.1575   |  40.22    |  0.7723   |
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1498]	train's auc: 0.911392	valid's auc: 0.879642
# |  40       |  0.8796   |  15.19    |  0.9073   |  165.5    |  192.6    |  0.03429  |  13.12    |  25.81    |  120.3    |  1.673    |  15.45    |  0.676    |
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [2622]	train's auc: 0.957262	valid's auc: 0.898317
# |  41       |  0.8983   |  19.93    |  0.7039   |  11.11    |  198.1    |  0.03122  |  13.24    |  245.8    |  137.5    |  1.929    |  184.4    |  0.8519   |
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1567]	train's auc: 0.949374	valid's auc: 0.896672
# |  42       |  0.8967   |  16.2     |  0.7039   |  10.7     |  141.1    |  0.04945  |  7.788    |  29.42    |  136.0    |  0.9535   |  199.4    |  0.624    |
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [2835]	train's auc: 0.957824	valid's auc: 0.898289
# |  43       |  0.8983   |  18.79    |  0.6633   |  11.3     |  105.1    |  0.02479  |  14.6     |  240.5    |  83.44    |  1.711    |  79.97    |  0.6161   |
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [4441]	train's auc: 0.941389	valid's auc: 0.897636
# |  44       |  0.8976   |  18.88    |  0.6748   |  12.19    |  96.77    |  0.02113  |  6.154    |  246.5    |  149.2    |  0.8414   |  132.7    |  0.4343   |
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1786]	train's auc: 0.977916	valid's auc: 0.895897
# |  45       |  0.8959   |  17.46    |  0.6946   |  23.43    |  132.5    |  0.03797  |  13.97    |  27.18    |  71.49    |  0.1046   |  57.91    |  0.8872   |
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [3402]	train's auc: 0.940623	valid's auc: 0.897923
# |  46       |  0.8979   |  19.76    |  0.5111   |  10.81    |  80.67    |  0.02631  |  5.935    |  148.4    |  71.72    |  1.477    |  196.4    |  0.4562   |
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1824]	train's auc: 0.953667	valid's auc: 0.898528
# |  47       |  0.8985   |  1.155    |  0.8854   |  15.82    |  88.41    |  0.04986  |  6.422    |  107.4    |  149.7    |  0.7372   |  49.51    |  0.6907   |
# Training until validation scores don't improve for 100 rounds.
# [5000]	train's auc: 0.926834	valid's auc: 0.891272
# Did not meet early stopping. Best iteration is:
# [5000]	train's auc: 0.926834	valid's auc: 0.891272
# |  48       |  0.8913   |  18.28    |  0.4603   |  13.36    |  185.3    |  0.007819 |  6.943    |  114.1    |  132.5    |  1.229    |  15.75    |  0.8169   |
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1779]	train's auc: 0.986411	valid's auc: 0.896217
# |  49       |  0.8962   |  17.47    |  0.7245   |  10.32    |  197.7    |  0.04191  |  14.51    |  132.3    |  51.59    |  0.3119   |  178.8    |  0.8116   |
# Training until validation scores don't improve for 100 rounds.
# [5000]	train's auc: 0.948856	valid's auc: 0.892975
# Did not meet early stopping. Best iteration is:
# [5000]	train's auc: 0.948856	valid's auc: 0.892975
# |  50       |  0.893    |  1.008    |  0.2617   |  11.48    |  14.14    |  0.005396 |  7.024    |  236.0    |  76.95    |  1.44     |  71.2     |  0.9401   |
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [3758]	train's auc: 0.961596	valid's auc: 0.900596
# |  51       |  0.9006   |  1.711    |  0.4232   |  11.02    |  25.34    |  0.02308  |  14.15    |  35.37    |  141.7    |  1.079    |  20.25    |  0.8907   |
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [2464]	train's auc: 0.915276	valid's auc: 0.889263
# |  52       |  0.8893   |  19.13    |  0.2661   |  80.68    |  69.85    |  0.02931  |  10.81    |  247.6    |  57.98    |  0.5539   |  194.8    |  0.3754   |
# Training until validation scores don't improve for 100 rounds.
# [5000]	train's auc: 0.90772	valid's auc: 0.880593
# Did not meet early stopping. Best iteration is:
# [4999]	train's auc: 0.90772	valid's auc: 0.880593
# |  53       |  0.8806   |  10.81    |  0.2141   |  187.7    |  52.08    |  0.0178   |  5.588    |  35.04    |  150.0    |  0.2693   |  197.6    |  0.792    |
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [3519]	train's auc: 0.955004	valid's auc: 0.899748
# |  54       |  0.8997   |  3.4      |  0.8502   |  10.62    |  175.8    |  0.02859  |  8.974    |  39.88    |  5.001    |  0.5389   |  15.1     |  0.8787   |
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [2077]	train's auc: 0.965005	valid's auc: 0.897935
# |  55       |  0.8979   |  9.206    |  0.6489   |  10.36    |  74.14    |  0.04763  |  5.381    |  151.3    |  4.633    |  0.6098   |  52.48    |  0.8186   |
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1062]	train's auc: 0.981732	valid's auc: 0.893962
# |  56       |  0.894    |  19.76    |  0.8798   |  15.32    |  14.04    |  0.03502  |  14.87    |  95.74    |  5.643    |  1.672    |  198.7    |  0.7652   |
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [2317]	train's auc: 0.926836	valid's auc: 0.889216
# |  57       |  0.8892   |  19.22    |  0.5911   |  114.7    |  45.77    |  0.02851  |  13.41    |  184.0    |  116.2    |  1.096    |  15.25    |  0.8093   |
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1105]	train's auc: 0.944028	valid's auc: 0.890819
# |  58       |  0.8908   |  17.37    |  0.7035   |  66.12    |  24.22    |  0.04779  |  14.63    |  248.1    |  4.286    |  1.465    |  51.64    |  0.6521   |
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1619]	train's auc: 0.956234	valid's auc: 0.898608
# |  59       |  0.8986   |  3.593    |  0.2249   |  10.02    |  32.1     |  0.04281  |  13.73    |  80.22    |  145.0    |  0.6995   |  195.7    |  0.5994   |
# Training until validation scores don't improve for 100 rounds.
# [5000]	train's auc: 0.944596	valid's auc: 0.888553
# Did not meet early stopping. Best iteration is:
# [5000]	train's auc: 0.944596	valid's auc: 0.888553
# |  60       |  0.8886   |  19.21    |  0.6125   |  83.19    |  197.8    |  0.007703 |  14.44    |  27.8     |  73.25    |  0.328    |  192.6    |  0.9001   |
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [3976]	train's auc: 0.993008	valid's auc: 0.895932
# |  61       |  0.8959   |  17.65    |  0.9285   |  13.62    |  150.4    |  0.01613  |  13.98    |  90.67    |  3.933    |  0.362    |  196.8    |  0.7455   |
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1736]	train's auc: 0.974195	valid's auc: 0.897517
# |  62       |  0.8975   |  2.809    |  0.7088   |  10.83    |  63.71    |  0.03737  |  11.88    |  29.42    |  143.1    |  0.6211   |  115.3    |  0.8823   |
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1966]	train's auc: 0.94707	valid's auc: 0.898866
# |  63       |  0.8989   |  2.924    |  0.6059   |  11.55    |  104.4    |  0.04977  |  5.604    |  27.37    |  110.2    |  1.115    |  26.82    |  0.6541   |
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [2584]	train's auc: 0.957731	valid's auc: 0.898609
# |  64       |  0.8986   |  19.98    |  0.2517   |  24.65    |  19.86    |  0.04202  |  6.726    |  246.6    |  75.83    |  0.5577   |  196.3    |  0.8087   |
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [4125]	train's auc: 0.971235	valid's auc: 0.899414
# |  65       |  0.8994   |  5.786    |  0.6806   |  14.5     |  27.89    |  0.02031  |  13.43    |  212.4    |  7.519    |  1.908    |  197.5    |  0.6691   |
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [2732]	train's auc: 0.961489	valid's auc: 0.899887
# |  66       |  0.8999   |  1.831    |  0.6247   |  10.65    |  98.81    |  0.03003  |  13.64    |  230.8    |  138.8    |  1.746    |  30.45    |  0.927    |
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [2578]	train's auc: 0.858815	valid's auc: 0.841234
# |  67       |  0.8412   |  14.33    |  0.4221   |  183.3    |  16.4     |  0.007911 |  8.327    |  246.0    |  3.212    |  0.7654   |  193.7    |  0.2817   |
# Training until validation scores don't improve for 100 rounds.
# [5000]	train's auc: 0.92172	valid's auc: 0.885478
# Did not meet early stopping. Best iteration is:
# [5000]	train's auc: 0.92172	valid's auc: 0.885478
# |  68       |  0.8855   |  15.46    |  0.3151   |  191.0    |  198.1    |  0.01123  |  12.42    |  33.72    |  1.837    |  1.028    |  197.8    |  0.8042   |
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [2736]	train's auc: 0.944212	valid's auc: 0.899657
# |  69       |  0.8997   |  19.43    |  0.277    |  14.5     |  193.2    |  0.0377   |  14.28    |  69.55    |  19.26    |  1.844    |  22.58    |  0.7394   |
# Training until validation scores don't improve for 100 rounds.
# Early stopping, best iteration is:
# [1450]	train's auc: 0.962669	valid's auc: 0.895208
# |  70       |  0.8952   |  17.9     |  0.7119   |  41.96    |  10.45    |  0.04708  |  14.72    |  157.9    |  80.83    |  0.6373   |  197.1    |  0.8574   |
# =============================================================================================================================================================
# -----------------------------------------------------
# Final Results
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-70adb469094d> in <module>()
#      24     print('-' * 53)
#      25     print('Final Results')
# ---> 26     print('LGB: %f' % lgbBO.res['max']['max_val']);  print('LGB: %s' % lgbBO.res['max']['max_params'])
#      27
#      28     param_list.append(lgbBO.res['max']['max_params'])
#
# TypeError: list indices must be integers or slices, not str
